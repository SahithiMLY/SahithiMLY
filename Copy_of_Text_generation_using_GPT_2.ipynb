# %%
# !pip install transformers datasets torch accelerate
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (5.12.0)
# Requirement already satisfied: datasets in /usr/local/lib/python3.12/dist-packages (4.0.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (2.11.0+cpu)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.12/dist-packages (1.14.0)
# Requirement already satisfied: huggingface-hub<2.0,>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (1.19.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (26.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex>=2025.10.22 in /usr/local/lib/python3.12/dist-packages (from transformers) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.2)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from transformers) (0.25.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.8.0)
# Requirement already satisfied: tqdm>=4.60 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets) (3.29.3)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.12/dist-packages (from datasets) (2.32.4)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets) (3.7.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2025.3.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.12/dist-packages (from torch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.14.1)
# Requirement already satisfied: click>=8.4.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (8.4.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (1.5.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (0.28.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (2026.5.20)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->transformers) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /usr/local/lib/python3.12/dist-packages (from typer->transformers) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->transformers) (0.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch) (3.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2026.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2.6.2)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.24.2)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (4.13.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (0.16.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer->transformers) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer->transformers) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer->transformers) (0.1.2)

# %%
from transformers import pipeline

generator = pipeline(
    "text-generation",
    model="gpt2"
)
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]

# %%
prompt = "Artificial Intelligence is"

result = generator(
    prompt,
    max_length=100,
    num_return_sequences=3
)

for i, output in enumerate(result):
    print(f"\nOutput {i+1}")
    print(output["generated_text"])
# Out:
# [transformers] Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [transformers] Both `max_new_tokens` (=256) and `max_length`(=100) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Output 1
# Artificial Intelligence is, in my opinion, most likely to be a very good idea.
#
# However, I would be remiss if I didn't mention that I have been impressed by the success of AI in the past:
#
# It is possible that AI may become a major force in the future – it could help make the world a better place. However, in the long term, this may mean that AI will only be useful in the short term – it is not as a threat that needs to be dealt with.
#
# So far, I have already given a brief overview of the real world and the world of AI, but I think I would like to share some more about the way we are seeing it.
#
# Is AI as good as it says on the tin?
#
# In a nutshell, yes, AI is very good. But let's look at what it is actually doing.
#
# First and foremost, AI is doing something. It's doing something to help us understand the world around us.
#
# That's the "what is AI?", or what it is really doing.
#
# We see that there is a lot of good news and bad news, but there is also a lot of bad news.
#
# First and foremost, it is doing something
#
# Output 2
# Artificial Intelligence is one of the most exciting new technologies in the world. As we discuss this, let's look at some of the interesting aspects of the technology and why it is so exciting. We'll also discuss the ways in which artificial intelligence could help us solve many of our problems, from health to education.
#
# What is Artificial Intelligence?
#
# A AI is a type of machine that works on human tasks and needs to be trained. A machine is an individual that is able to learn how to interact with other human beings. This type of AI, called AI-assisted learning, is often called "human brain" or "brain of the future."
#
# The most recent examples of AI research are research into how human-computer interfaces can be used to solve some of the most complex problems. One of the most exciting challenges AI is facing is how to get humans to interact with machines.
#
# A team from MIT has been developing a way to develop a robot that works on human tasks. This robot has a human-computer interface that uses the voice of its voice to input a list of information. It can be programmed to act on humans even though the robot doesn't know what those information is. The robot is able to learn to use its voice to learn how to interact with
#
# Output 3
# Artificial Intelligence is one of the most exciting developments in the field, and it is certainly something that has been in the works for many years. But it is also a great step forward in the field.
#
# If Artificial Intelligence is to become the new way of thinking about humans, it needs to be implemented in a way that is accessible to the next generations, as well as to the general public and other people, and that involves making sure that it is a part of a broader understanding of what people need.
#
# This is what I'm calling the artificial intelligence approach. I'm talking about the idea that we can interact with machines by manipulating them. We can perform complex tasks, we can do things like send a message in real time, we can do something like make a computer that does something, or we can do some other way.
#
# This approach is about the use of computational models as a way of understanding what people need, and how they use it. It's about understanding how people do things, how they use it, and how they use it in their daily lives.
#
# We can begin to understand what people want from themselves and their family, and how we respond to that. Maybe we start to understand that we are not the only ones who are trying to understand

# %%
# !ls
# Out:
# ai_dataset.txt	gpt2-finetuned	sample_data

# %%
sample_data = """
Artificial Intelligence is transforming industries worldwide.
Machine learning helps computers learn from data.
Deep learning uses neural networks to solve complex problems.
Generative AI can create text, images, and code.
Python is a popular programming language for AI.
Data analytics helps organizations make informed decisions.
Large language models understand and generate human language.
AI is widely used in healthcare and education.
Business intelligence converts data into useful insights.
Data science combines statistics and programming.
AI improves customer experience through automation.
Machine learning algorithms detect patterns in data.
Natural language processing enables machines to understand text.
Computer vision helps computers analyze images.
AI-powered chatbots assist users efficiently.
Data visualization makes information easier to understand.
Predictive analytics forecasts future trends.
Deep learning powers modern AI applications.
Artificial Intelligence is changing the future of technology.
Neural networks mimic the human brain.
AI helps businesses improve productivity.
Cloud computing supports AI applications.
Big data provides valuable information for AI models.
Recommendation systems personalize user experiences.
AI is used in self-driving cars.
Healthcare uses AI for disease prediction.
Educational platforms use AI for personalized learning.
Cybersecurity systems use AI to detect threats.
AI enhances decision-making processes.
Machine learning improves over time with more data.
Data engineers build data pipelines.
AI can automate repetitive tasks.
Generative AI creates creative content.
Large datasets improve model performance.
AI research continues to grow rapidly.
Technology companies invest heavily in AI.
AI assists scientists in data analysis.
Smart assistants use natural language processing.
Data quality is important for machine learning.
AI is revolutionizing many industries.
"""

# %%
with open("ai_dataset.txt", "w") as f:
    f.write(sample_data)

print("Dataset updated successfully!")
# Out:
# Dataset updated successfully!

# %%
with open("ai_dataset.txt", "r") as f:
    print(f.read())
# Out:
# Artificial Intelligence is transforming industries worldwide.
# Machine learning helps computers learn from data.
# Deep learning uses neural networks to solve complex problems.
# Generative AI can create text, images, and code.
# Python is a popular programming language for AI.
# Data analytics helps organizations make informed decisions.
# Large language models understand and generate human language.
# AI is widely used in healthcare and education.
# Business intelligence converts data into useful insights.
# Data science combines statistics and programming.
# AI improves customer experience through automation.
# Machine learning algorithms detect patterns in data.
# Natural language processing enables machines to understand text.
# Computer vision helps computers analyze images.
# AI-powered chatbots assist users efficiently.
# Data visualization makes information easier to understand.
# Predictive analytics forecasts future trends.
# Deep learning powers modern AI applications.
# Artificial Intelligence is changing the future of technology.
# Neural networks mimic the human brain.
# AI helps businesses improve productivity.
# Cloud computing supports AI applications.
# Big data provides valuable information for AI models.
# Recommendation systems personalize user experiences.
# AI is used in self-driving cars.
# Healthcare uses AI for disease prediction.
# Educational platforms use AI for personalized learning.
# Cybersecurity systems use AI to detect threats.
# AI enhances decision-making processes.
# Machine learning improves over time with more data.
# Data engineers build data pipelines.
# AI can automate repetitive tasks.
# Generative AI creates creative content.
# Large datasets improve model performance.
# AI research continues to grow rapidly.
# Technology companies invest heavily in AI.
# AI assists scientists in data analysis.
# Smart assistants use natural language processing.
# Data quality is important for machine learning.
# AI is revolutionizing many industries.

# %%
# !pip install -q transformers datasets accelerate

# %%
from transformers import GPT2Tokenizer, GPT2LMHeadModel

tokenizer = GPT2Tokenizer.from_pretrained("gpt2")
model = GPT2LMHeadModel.from_pretrained("gpt2")

print("GPT-2 loaded successfully!")
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT-2 loaded successfully!

# %%
from datasets import load_dataset

dataset = load_dataset(
    "text",
    data_files={"train": "ai_dataset.txt"}
)

print(dataset)
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['text'],
#         num_rows: 41
#     })
# })

# %%
print(dataset["train"][0])
# Out:
# {'text': ''}

# %%
sample_data = """
Artificial Intelligence is transforming industries worldwide.
Machine learning helps computers learn from data.
Deep learning uses neural networks to solve complex problems.
Generative AI can create text, images, and code.
Python is a popular programming language for AI.
Data analytics helps organizations make informed decisions.
Large language models understand and generate human language.
AI is widely used in healthcare and education.
Business intelligence converts data into useful insights.
Data science combines statistics and programming.
AI improves customer experience through automation.
Machine learning algorithms detect patterns in data.
Natural language processing enables machines to understand text.
Computer vision helps computers analyze images.
AI-powered chatbots assist users efficiently.
Data visualization makes information easier to understand.
Predictive analytics forecasts future trends.
Deep learning powers modern AI applications.
Artificial Intelligence is changing the future of technology.
Neural networks mimic the human brain.
AI helps businesses improve productivity.
Cloud computing supports AI applications.
Big data provides valuable information for AI models.
Recommendation systems personalize user experiences.
AI is used in self-driving cars.
Healthcare uses AI for disease prediction.
Educational platforms use AI for personalized learning.
Cybersecurity systems use AI to detect threats.
AI enhances decision-making processes.
Machine learning improves over time with more data.
Data engineers build data pipelines.
AI can automate repetitive tasks.
Generative AI creates creative content.
Large datasets improve model performance.
AI research continues to grow rapidly.
Technology companies invest heavily in AI.
AI assists scientists in data analysis.
Smart assistants use natural language processing.
Data quality is important for machine learning.
AI is revolutionizing many industries.
"""

# %%
tokenizer.pad_token = tokenizer.eos_token

print("Padding token fixed!")
# Out:
# Padding token fixed!

# %%
def tokenize_function(examples):
    return tokenizer(
        examples["text"],
        truncation=True,
        padding="max_length",
        max_length=128
    )

tokenized_dataset = dataset.map(
    tokenize_function,
    batched=True
)

print("Tokenization completed!")
# Out:
# Map:   0%|          | 0/41 [00:00<?, ? examples/s]
# Tokenization completed!

# %%
from transformers import DataCollatorForLanguageModeling

data_collator = DataCollatorForLanguageModeling(
    tokenizer=tokenizer,
    mlm=False
)

print("Data Collator Created!")
# Out:
# Data Collator Created!

# %%
from transformers import TrainingArguments

training_args = TrainingArguments(
    output_dir="./gpt2-finetuned",
    num_train_epochs=3,
    per_device_train_batch_size=2
)

print("Training Arguments Created!")
# Out:
# Training Arguments Created!

# %%
from transformers import Trainer

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_dataset["train"],
    data_collator=data_collator,
)

print("Trainer Created!")
# Out:
# Trainer Created!

# %%
trainer.train()
# Out:
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
#     <div>
#
#       <progress value='63' max='63' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [63/63 05:52, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# TrainOutput(global_step=63, training_loss=2.4445032997736855, metrics={'train_runtime': 370.359, 'train_samples_per_second': 0.332, 'train_steps_per_second': 0.17, 'total_flos': 8034729984000.0, 'train_loss': 2.4445032997736855, 'epoch': 3.0})

# %%
prompt = "Artificial Intelligence"

output = model.generate(
    tokenizer(prompt, return_tensors="pt").input_ids,
    max_length=100,
    num_return_sequences=3,
    do_sample=True
)

for i, text in enumerate(output):
    print(f"\nOutput {i+1}:")
    print(tokenizer.decode(text, skip_special_tokens=True))
# Out:
# [transformers] The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# [transformers] Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Output 1:
# Artificial Intelligence uses AI for AI applications. AI helps businesses improve productivity. AI enables businesses to improve productivity and automate tasks. AI enables businesses to improve productivity. AI enables businesses to build customer experiences. AI enables businesses to deliver better data. AI enables enterprises improve customer experiences. Artificial Intelligence enables data to be understood and applied in machines. AI enables software automation. AI enables data is accessible to automation systems. In addition, AI enables computing. AI enables automation. AI creates new products. AI creates products
#
# Output 2:
# Artificial Intelligence develops systems that enhance productivity.
#
#
# As robots assist human users, AI makes AI smarter. Computer vision, deep learning and interactive content create visual content.
#
# As more AI improves productivity, technology improves AI. AI is developing AI platforms for both for industries and individuals use everyday.
#
# Machine learning applications use AI to automate complex tasks and solve complex problems.
#
# Data scientists use artificial intelligence to automate tasks. AI enables scientists to solve complex problems faster.
#
# Output 3:
# Artificial Intelligence is transforming industries worldwide. Already millions of people consume data. Machines can solve complex problems. Yet machines are becoming more efficient. But humans are less intelligent. While AI improves our behavior, humans need more data.
#
# Machine learning algorithms solve complex problems. Machine learning creates new insights. And machine learning helps machine understand data. But AI creates new insights.
#
# Machine learning advances AI technology. AI algorithms improve AI applications. The results of AI applications are increasingly automated. Because of AI
