# %% [markdown]
# <a href="https://colab.research.google.com/github/SahithiMLY/SahithiMLY/blob/main/Text_Generation_using_GPT_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers torch

# %%
from transformers import pipeline

generator = pipeline(
    "text-generation",
    model="gpt2"
)

prompt = "Artificial Intelligence is"

result = generator(
    prompt,
    max_length=100,
    num_return_sequences=1
)

print(result[0]["generated_text"])
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# [transformers] Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [transformers] Both `max_new_tokens` (=256) and `max_length`(=100) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Artificial Intelligence is here to stay.
#
# The latest major breakthrough in artificial intelligence comes from a new study from MIT's Artificial Intelligence Laboratory. The research, led by a team led by MIT's Richard Moore, makes it possible to use real-world data to design machines that recognize and respond to the human eye in real-time.
#
# ...

# %%
from transformers import pipeline

generator = pipeline(
    "text-generation",
    model="gpt2"
)

prompt = "The future of Generative AI in healthcare is"

result = generator(
    prompt,
    max_length=100,
    num_return_sequences=3
)

for i in result:
    print(i["generated_text"])
    print("-"*50)
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# [transformers] Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [transformers] Both `max_new_tokens` (=256) and `max_length`(=100) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# The future of Generative AI in healthcare is in question. Most of the work we have done to make it happen is to create a system where we can work with our AI to provide the healthcare we need. By working with the AI, we can provide patients with the best healthcare possible.
#
# When I first started working with Generative AI in the early 2000s, I would do my best to make it easy for patients to find care within our company. I would give patients whatever care they needed. I would give them something that was better than what they had at home.
#
# ...

# %%
num_return_sequences=3
